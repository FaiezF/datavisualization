# %%
import pandas as pd
df = pd.read_csv("C:\Users\cabin\Desktop\titanic-passengers.csv")
# Out:
#   File "<ipython-input-12-87b507655a4b>", line 2
#     df = pd.read_csv("C:\Users\cabin\Desktop\titanic-passengers.csv")
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
